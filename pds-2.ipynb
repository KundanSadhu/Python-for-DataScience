# %%
def sum_digits(product_code):
    # Base case
    if product_code == 0:
        return 0

    # Recursive case
    return (product_code % 10) + sum_digits(product_code // 10)


code_text = input("Enter the Product Code: ").strip()

if code_text.isdigit():
    product_code = int(code_text)
    print("Sum of Digits =", sum_digits(product_code))
else:
    print("Invalid product code. Please enter digits only.")
# Out:
# Enter the Product Code: 45892
# Sum of Digits = 28
